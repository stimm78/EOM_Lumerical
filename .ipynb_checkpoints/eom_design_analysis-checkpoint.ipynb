# %%
import lumerical as lum
import LDEV_Functions as ldf
# import DC_Functions as dc
import numpy as  np
from scipy import signal as si
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import imp
import time
import csv
import matplotlib.patches as patches
from scipy.integrate import simps
from scipy.integrate import odeint
from scipy.integrate import solve_ivp
from scipy.optimize import minimize
from numpy import genfromtxt
from scipy.constants import pi, c, epsilon_0
from scipy.interpolate import CubicSpline

#Basic units
pm = 1e-12
nm = 1e-9
um = 1e-6
mm = 1e-3
ps = 1e-12
fs = 1e-15
GHz = 1e9
THz = 1e12
pJ = 1e-12
mW = 1e-3
deg = pi/180 #This is used to convert from deg to radians for trig functions

meshsize = 50*nm
finemesh = 10*nm

ldf.initializeDEVICE()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import lumerical as lum
#       2 import LDEV_Functions as ldf
#       3 # import DC_Functions as dc
#
# ModuleNotFoundError: No module named 'lumerical'
